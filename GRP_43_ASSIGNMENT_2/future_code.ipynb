# %%
class_names=["Disease","no_disease"] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 427.9555555555555, 'Predicted label')

# %%
X_train_min = X_train.min()
X_train_min

X_train_max = X_train.max()
X_train_max

X_train_range = (X_train_max- X_train_min)
X_train_range

X_train_scaled = (X_train - X_train_min)/(X_train_range)
X_train_scaled.head()

X_test_min = X_test.min()
X_test_range = (X_test - X_test_min).max()
X_test_scaled = (X_test - X_test_min)/X_test_range

svc_model = SVC()
svc_model.fit(X_train_scaled, y_train)

y_predict_svc_scaled = svc_model.predict(X_test_scaled)
cm_svc_scaled = confusion_matrix(y_test, y_predict_svc_scaled)

cm_svc_scaled

sns.heatmap(cm_svc_scaled,annot=True,fmt="d")

print(classification_report(y_test,y_predict_svc_scaled))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83        41
#            1       0.78      0.89      0.83        35
#
#     accuracy                           0.83        76
#    macro avg       0.83      0.83      0.83        76
# weighted avg       0.84      0.83      0.83        76
